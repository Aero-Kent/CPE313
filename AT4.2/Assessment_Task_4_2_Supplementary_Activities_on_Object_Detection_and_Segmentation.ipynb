# %% [markdown]
# # Transforms v2: End-to-end object detection/segmentation example
#
# <div class="alert alert-info"><h4>Note</h4><p>Try on [Colab](https://colab.research.google.com/github/pytorch/vision/blob/gh-pages/main/_generated_ipynb_notebooks/plot_transforms_e2e.ipynb)
#     or `go to the end <sphx_glr_download_auto_examples_transforms_plot_transforms_e2e.py>` to download the full example code.</p></div>
#
# Object detection and segmentation tasks are natively supported:
# ``torchvision.transforms.v2`` enables jointly transforming images, videos,
# bounding boxes, and masks.
#
# This example showcases an end-to-end instance segmentation training case using
# Torchvision utils from ``torchvision.datasets``, ``torchvision.models`` and
# ``torchvision.transforms.v2``. Everything covered here can be applied similarly
# to object detection or semantic segmentation tasks.

# %%
import kagglehub

path = kagglehub.dataset_download("pkdarabi/brain-tumor-image-dataset-semantic-segmentation")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'brain-tumor-image-dataset-semantic-segmentation' dataset.
# Path to dataset files: /kaggle/input/brain-tumor-image-dataset-semantic-segmentation

# %%
import pathlib

import torch
import torch.utils.data

from torchvision import models, datasets, tv_tensors
from torchvision.transforms import v2

torch.manual_seed(0)

# This loads fake data for illustration purposes of this example. In practice, you'll have
# to replace this with the proper data.
# If you're trying to run that on Colab, you can download the assets and the
# helpers from https://github.com/pytorch/vision/tree/main/gallery/
# ROOT = pathlib.Path("../assets") / "coco"
# IMAGES_PATH = str(ROOT / "images")
# ANNOTATIONS_PATH = str(ROOT / "instances.json")

DATA_ROOT = pathlib.Path("/root/.cache/kagglehub/datasets/pkdarabi/brain-tumor-image-dataset-semantic-segmentation/versions/1")
train_images = DATA_ROOT / "train"
test_images = DATA_ROOT / "test"
valid_images = DATA_ROOT / "valid"
train_annotations = train_images / "_annotations.coco.json"
test_annotations = valid_images / "_annotations.coco.json"
valid_annotations = valid_images / "_annotations.coco.json"

from helpers import plot

# %% [markdown]
# ***https://github.com/pytorch/vision/blob/main/gallery/transforms/helpers.py***

# %% [markdown]
# ## Dataset preparation
#
# We start off by loading the :class:`~torchvision.datasets.CocoDetection` dataset to have a look at what it currently
# returns.

# %%
# dataset = datasets.CocoDetection(IMAGES_PATH, ANNOTATIONS_PATH)
train_dataset = datasets.CocoDetection(
    root=str(train_images),
    annFile=str(train_annotations)
)

test_dataset = datasets.CocoDetection(
    root=str(test_images),
    annFile=str(test_annotations)
)

valid_dataset = datasets.CocoDetection(
    root=str(valid_images),
    annFile=str(valid_annotations)
)

# sample = dataset[0]
sample = train_dataset[0]
img, target = sample
print(f"{type(img) = }\n{type(target) = }\n{type(target[0]) = }\n{target[0].keys() = }")
# Out:
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# type(img) = <class 'PIL.Image.Image'>
# type(target) = <class 'list'>
# type(target[0]) = <class 'dict'>
# target[0].keys() = dict_keys(['id', 'image_id', 'category_id', 'bbox', 'area', 'segmentation', 'iscrowd'])

# %% [markdown]
# Torchvision datasets preserve the data structure and types as it was intended
# by the datasets authors. So by default, the output structure may not always be
# compatible with the models or the transforms.
#
# To overcome that, we can use the
# :func:`~torchvision.datasets.wrap_dataset_for_transforms_v2` function. For
# :class:`~torchvision.datasets.CocoDetection`, this changes the target
# structure to a single dictionary of lists:

# %%
# dataset = datasets.wrap_dataset_for_transforms_v2(dataset, target_keys=("boxes", "labels", "masks"))
train_dataset = datasets.wrap_dataset_for_transforms_v2(train_dataset, target_keys=("boxes", "labels", "masks"))
test_dataset = datasets.wrap_dataset_for_transforms_v2(test_dataset, target_keys=("boxes", "labels", "masks"))
valid_dataset = datasets.wrap_dataset_for_transforms_v2(valid_dataset, target_keys=("boxes", "labels", "masks"))

sample = train_dataset[0]
img, target = sample
print(f"{type(img) = }\n{type(target) = }\n{target.keys() = }")
print(f"{type(target['boxes']) = }\n{type(target['labels']) = }\n{type(target['masks']) = }")
# Out:
# type(img) = <class 'PIL.Image.Image'>
# type(target) = <class 'dict'>
# target.keys() = dict_keys(['boxes', 'masks', 'labels'])
# type(target['boxes']) = <class 'torchvision.tv_tensors._bounding_boxes.BoundingBoxes'>
# type(target['labels']) = <class 'torch.Tensor'>
# type(target['masks']) = <class 'torchvision.tv_tensors._mask.Mask'>

# %% [markdown]
# We used the ``target_keys`` parameter to specify the kind of output we're
# interested in. Our dataset now returns a target which is dict where the values
# are `TVTensors <what_are_tv_tensors>` (all are :class:`torch.Tensor`
# subclasses). We're dropped all unncessary keys from the previous output, but
# if you need any of the original keys e.g. "image_id", you can still ask for
# it.
#
# <div class="alert alert-info"><h4>Note</h4><p>If you just want to do detection, you don't need and shouldn't pass
#     "masks" in ``target_keys``: if masks are present in the sample, they will
#     be transformed, slowing down your transformations unnecessarily.</p></div>
#
# As baseline, let's have a look at a sample without transformations:

# %%
plot([train_dataset[0], train_dataset[1]])

# %% [markdown]
# ## Transforms
#
# Let's now define our pre-processing transforms. All the transforms know how
# to handle images, bounding boxes and masks when relevant.
#
# Transforms are typically passed as the ``transforms`` parameter of the
# dataset so that they can leverage multi-processing from the
# :class:`torch.utils.data.DataLoader`.

# %%
transforms = v2.Compose(
    [
        v2.ToImage(),
        v2.RandomPhotometricDistort(p=1),
        v2.RandomZoomOut(fill={tv_tensors.Image: (123, 117, 104), "others": 0}),
        v2.RandomIoUCrop(),
        v2.RandomHorizontalFlip(p=1),
        v2.SanitizeBoundingBoxes(),
        v2.ToDtype(torch.float32, scale=True),
    ]
)

# dataset = datasets.CocoDetection(IMAGES_PATH, ANNOTATIONS_PATH, transforms=transforms)
# dataset = datasets.wrap_dataset_for_transforms_v2(dataset, target_keys=["boxes", "labels", "masks"])

train_dataset = datasets.CocoDetection(
    root=str(train_images),
    annFile=str(train_annotations),
    transforms=transforms
)

test_dataset = datasets.CocoDetection(
    root=str(test_images),
    annFile=str(test_annotations),
    transforms=transforms
)

valid_dataset = datasets.CocoDetection(
    root=str(valid_images),
    annFile=str(valid_annotations),
    transforms=transforms
)

train_dataset = datasets.wrap_dataset_for_transforms_v2(train_dataset, target_keys=("boxes", "labels", "masks"))
test_dataset = datasets.wrap_dataset_for_transforms_v2(test_dataset, target_keys=("boxes", "labels", "masks"))
valid_dataset = datasets.wrap_dataset_for_transforms_v2(valid_dataset, target_keys=("boxes", "labels", "masks"))
# Out:
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!

# %% [markdown]
# A few things are worth noting here:
#
# - We're converting the PIL image into a
#   :class:`~torchvision.transforms.v2.Image` object. This isn't strictly
#   necessary, but relying on Tensors (here: a Tensor subclass) will
#   `generally be faster <transforms_perf>`.
# - We are calling :class:`~torchvision.transforms.v2.SanitizeBoundingBoxes` to
#   make sure we remove degenerate bounding boxes, as well as their
#   corresponding labels and masks.
#   :class:`~torchvision.transforms.v2.SanitizeBoundingBoxes` should be placed
#   at least once at the end of a detection pipeline; it is particularly
#   critical if :class:`~torchvision.transforms.v2.RandomIoUCrop` was used.
#
# Let's look how the sample looks like with our augmentation pipeline in place:

# %%
plot([train_dataset[0], train_dataset[1]])

# %% [markdown]
# We can see that the color of the images were distorted, zoomed in or out, and flipped.
# The bounding boxes and the masks were transformed accordingly. And without any further ado, we can start training.
#
# ## Data loading and training loop
#
# Below we're using Mask-RCNN which is an instance segmentation model, but
# everything we've covered in this tutorial also applies to object detection and
# semantic segmentation tasks.

# %%
torch.cuda.empty_cache() # use if gpu ram stuck is stuck

# %%
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print("Using device:", device)
# Out:
# Using device: cuda

# %%
# data_loader = torch.utils.data.DataLoader(
#     dataset,
#     batch_size=2,
#     # We need a custom collation function here, since the object detection
#     # models expect a sequence of images and target dictionaries. The default
#     # collation function tries to torch.stack() the individual elements,
#     # which fails in general for object detection, because the number of bounding
#     # boxes varies between the images of the same batch.
#     collate_fn=lambda batch: tuple(zip(*batch)),
# )

# for imgs, targets in data_loader:
#     loss_dict = model(imgs, targets)
#     # Put your training logic here

#     print(f"{[img.shape for img in imgs] = }")
#     print(f"{[type(target) for target in targets] = }")
#     for name, loss_val in loss_dict.items():
#         print(f"{name:<20}{loss_val:.3f}")

device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print("Using device:", device)

batch_size = 1 # cuda keeps OutOfMemoryError: so size is set to > 1

train_loader = torch.utils.data.DataLoader(
  train_dataset,
  batch_size=batch_size,
  shuffle=True,
  collate_fn=lambda batch: tuple(zip(*batch)),
)

valid_loader = torch.utils.data.DataLoader(
  valid_dataset,
  batch_size=batch_size,
  shuffle=False,
  collate_fn=lambda batch: tuple(zip(*batch)),
)

model = models.get_model("maskrcnn_resnet50_fpn_v2", weights=None, weights_backbone=None).to(device)
model.train()
optimizer = torch.optim.SGD(model.parameters(), lr=0.005, momentum=0.9, weight_decay=0.0005)

for i, (imgs, targets) in enumerate(train_loader, 1):
  imgs = [img.to(device) for img in imgs]
  targets = [{k: v.to(device) if torch.is_tensor(v) else v for k, v in t.items()} for t in targets]
  loss_dict = model(imgs, targets)
  losses = sum(loss for loss in loss_dict.values())
  optimizer.zero_grad()
  losses.backward()
  optimizer.step()
  torch.cuda.empty_cache()

  print(f"\n=== {i+1} ===")
  print(f"{[img.shape for img in imgs] = }")
  print(f"{[type(target) for target in targets] = }")
  for name, loss_val in loss_dict.items():
    print(f"{name:<20}{loss_val:.3f}")
  if i == 400: break # only uses about 1/3 the data for this example
# Out:
# Using device: cuda
#
# === 2 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     4.748
# loss_box_reg        0.010
# loss_mask           0.723
# loss_objectness     0.694
# loss_rpn_box_reg    0.006
#
# === 3 ===
# [img.shape for img in imgs] = [torch.Size([3, 1392, 1392])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     3.354
# loss_box_reg        0.045
# loss_mask           0.697
# loss_objectness     0.692
# loss_rpn_box_reg    0.012
#
# === 4 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     1.090
# loss_box_reg        0.004
# loss_mask           0.631
# loss_objectness     0.691
# loss_rpn_box_reg    0.001
#
# === 5 ===
# [img.shape for img in imgs] = [torch.Size([3, 2409, 2409])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.346
# loss_box_reg        0.066
# loss_mask           0.637
# loss_objectness     0.688
# loss_rpn_box_reg    0.003
#
# === 6 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.066
# loss_box_reg        0.017
# loss_mask           0.862
# loss_objectness     0.684
# loss_rpn_box_reg    0.006
#
# === 7 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.061
# loss_box_reg        0.006
# loss_mask           0.441
# loss_objectness     0.682
# loss_rpn_box_reg    0.003
#
# === 8 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.094
# loss_box_reg        0.019
# loss_mask           0.561
# loss_objectness     0.678
# loss_rpn_box_reg    0.001
#
# === 9 ===
# [img.shape for img in imgs] = [torch.Size([3, 1929, 1929])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.396
# loss_box_reg        0.049
# loss_mask           0.456
# loss_objectness     0.675
# loss_rpn_box_reg    0.004
#
# === 10 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.091
# loss_box_reg        0.014
# loss_mask           0.322
# loss_objectness     0.665
# loss_rpn_box_reg    0.006
#
# === 11 ===
# [img.shape for img in imgs] = [torch.Size([3, 1913, 1913])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.627
# loss_box_reg        0.031
# loss_mask           0.691
# loss_objectness     0.668
# loss_rpn_box_reg    0.005
#
# === 12 ===
# [img.shape for img in imgs] = [torch.Size([3, 892, 892])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.249
# loss_box_reg        0.009
# loss_mask           0.647
# loss_objectness     0.657
# loss_rpn_box_reg    0.003
#
# === 13 ===
# [img.shape for img in imgs] = [torch.Size([3, 1747, 1747])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.654
# loss_box_reg        0.016
# loss_mask           0.189
# loss_objectness     0.655
# loss_rpn_box_reg    0.001
#
# === 14 ===
# [img.shape for img in imgs] = [torch.Size([3, 1098, 1098])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.429
# loss_box_reg        0.006
# loss_mask           0.161
# loss_objectness     0.651
# loss_rpn_box_reg    0.015
#
# === 15 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.261
# loss_box_reg        0.009
# loss_mask           0.477
# loss_objectness     0.635
# loss_rpn_box_reg    0.007
#
# === 16 ===
# [img.shape for img in imgs] = [torch.Size([3, 1754, 1754])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.595
# loss_box_reg        0.028
# loss_mask           0.126
# loss_objectness     0.638
# loss_rpn_box_reg    0.003
#
# === 17 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.109
# loss_box_reg        0.006
# loss_mask           0.372
# loss_objectness     0.616
# loss_rpn_box_reg    0.004
#
# === 18 ===
# [img.shape for img in imgs] = [torch.Size([3, 2176, 2176])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.661
# loss_box_reg        0.022
# loss_mask           0.096
# loss_objectness     0.636
# loss_rpn_box_reg    0.011
#
# === 19 ===
# [img.shape for img in imgs] = [torch.Size([3, 1459, 1459])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.443
# loss_box_reg        0.031
# loss_mask           0.282
# loss_objectness     0.614
# loss_rpn_box_reg    0.003
#
# === 20 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.121
# loss_box_reg        0.005
# loss_mask           0.237
# loss_objectness     0.591
# loss_rpn_box_reg    0.008
#
# === 21 ===
# [img.shape for img in imgs] = [torch.Size([3, 1023, 1023])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.208
# loss_box_reg        0.009
# loss_mask           0.217
# loss_objectness     0.585
# loss_rpn_box_reg    0.002
#
# === 22 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.090
# loss_box_reg        0.006
# loss_mask           0.057
# loss_objectness     0.568
# loss_rpn_box_reg    0.004
#
# === 23 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.125
# loss_box_reg        0.006
# loss_mask           0.156
# loss_objectness     0.558
# loss_rpn_box_reg    0.003
#
# === 24 ===
# [img.shape for img in imgs] = [torch.Size([3, 1435, 1435])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.188
# loss_box_reg        0.015
# loss_mask           0.052
# loss_objectness     0.573
# loss_rpn_box_reg    0.009
#
# === 25 ===
# [img.shape for img in imgs] = [torch.Size([3, 1861, 1861])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.226
# loss_box_reg        0.011
# loss_mask           0.188
# loss_objectness     0.582
# loss_rpn_box_reg    0.016
#
# === 26 ===
# [img.shape for img in imgs] = [torch.Size([3, 1589, 1589])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.132
# loss_box_reg        0.005
# loss_mask           0.127
# loss_objectness     0.545
# loss_rpn_box_reg    0.003
#
# === 27 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.084
# loss_box_reg        0.003
# loss_mask           0.080
# loss_objectness     0.515
# loss_rpn_box_reg    0.006
#
# === 28 ===
# [img.shape for img in imgs] = [torch.Size([3, 1775, 1775])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.140
# loss_box_reg        0.005
# loss_mask           0.170
# loss_objectness     0.523
# loss_rpn_box_reg    0.002
#
# === 29 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.068
# loss_box_reg        0.006
# loss_mask           0.030
# loss_objectness     0.494
# loss_rpn_box_reg    0.019
#
# === 30 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.061
# loss_box_reg        0.001
# loss_mask           0.074
# loss_objectness     0.450
# loss_rpn_box_reg    0.002
#
# === 31 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.067
# loss_box_reg        0.007
# loss_mask           0.044
# loss_objectness     0.445
# loss_rpn_box_reg    0.006
#
# === 32 ===
# [img.shape for img in imgs] = [torch.Size([3, 1566, 1566])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.058
# loss_box_reg        0.007
# loss_mask           0.076
# loss_objectness     0.453
# loss_rpn_box_reg    0.003
#
# === 33 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.070
# loss_box_reg        0.006
# loss_mask           0.066
# loss_objectness     0.399
# loss_rpn_box_reg    0.002
#
# === 34 ===
# [img.shape for img in imgs] = [torch.Size([3, 967, 967])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.060
# loss_box_reg        0.002
# loss_mask           0.101
# loss_objectness     0.382
# loss_rpn_box_reg    0.002
#
# === 35 ===
# [img.shape for img in imgs] = [torch.Size([3, 760, 760])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.039
# loss_box_reg        0.003
# loss_mask           0.064
# loss_objectness     0.375
# loss_rpn_box_reg    0.003
#
# === 36 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.073
# loss_box_reg        0.003
# loss_mask           0.051
# loss_objectness     0.334
# loss_rpn_box_reg    0.001
#
# === 37 ===
# [img.shape for img in imgs] = [torch.Size([3, 1730, 1730])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.039
# loss_box_reg        0.002
# loss_mask           0.046
# loss_objectness     0.349
# loss_rpn_box_reg    0.005
#
# === 38 ===
# [img.shape for img in imgs] = [torch.Size([3, 2355, 2355])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.046
# loss_box_reg        0.002
# loss_mask           0.058
# loss_objectness     0.346
# loss_rpn_box_reg    0.009
#
# === 39 ===
# [img.shape for img in imgs] = [torch.Size([3, 1137, 1137])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.038
# loss_box_reg        0.003
# loss_mask           0.032
# loss_objectness     0.251
# loss_rpn_box_reg    0.005
#
# === 40 ===
# [img.shape for img in imgs] = [torch.Size([3, 2229, 2229])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.040
# loss_box_reg        0.002
# loss_mask           0.151
# loss_objectness     0.343
# loss_rpn_box_reg    0.011
#
# === 41 ===
# [img.shape for img in imgs] = [torch.Size([3, 2358, 2358])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.037
# loss_box_reg        0.002
# loss_mask           0.047
# loss_objectness     0.283
# loss_rpn_box_reg    0.010
#
# === 42 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.138
# loss_box_reg        0.007
# loss_mask           0.487
# loss_objectness     0.170
# loss_rpn_box_reg    0.001
#
# === 43 ===
# [img.shape for img in imgs] = [torch.Size([3, 2160, 2160])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.028
# loss_box_reg        0.000
# loss_mask           0.029
# loss_objectness     0.243
# loss_rpn_box_reg    0.007
#
# === 44 ===
# [img.shape for img in imgs] = [torch.Size([3, 1622, 1622])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.020
# loss_box_reg        0.001
# loss_mask           0.035
# loss_objectness     0.150
# loss_rpn_box_reg    0.003
#
# === 45 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.063
# loss_box_reg        0.002
# loss_mask           0.042
# loss_objectness     0.136
# loss_rpn_box_reg    0.006
#
# === 46 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.063
# loss_box_reg        0.004
# loss_mask           0.023
# loss_objectness     0.111
# loss_rpn_box_reg    0.001
#
# === 47 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.039
# loss_box_reg        0.002
# loss_mask           0.057
# loss_objectness     0.115
# loss_rpn_box_reg    0.003
#
# === 48 ===
# [img.shape for img in imgs] = [torch.Size([3, 1163, 1163])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.017
# loss_box_reg        0.001
# loss_mask           0.041
# loss_objectness     0.104
# loss_rpn_box_reg    0.002
#
# === 49 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.046
# loss_box_reg        0.002
# loss_mask           0.031
# loss_objectness     0.085
# loss_rpn_box_reg    0.000
#
# === 50 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.176
# loss_box_reg        0.019
# loss_mask           0.117
# loss_objectness     0.085
# loss_rpn_box_reg    0.006
#
# === 51 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.034
# loss_box_reg        0.001
# loss_mask           0.030
# loss_objectness     0.126
# loss_rpn_box_reg    0.003
#
# === 52 ===
# [img.shape for img in imgs] = [torch.Size([3, 2178, 2178])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.008
# loss_box_reg        0.001
# loss_mask           0.282
# loss_objectness     1.473
# loss_rpn_box_reg    0.286
#
# === 53 ===
# [img.shape for img in imgs] = [torch.Size([3, 2037, 2037])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.008
# loss_box_reg        0.001
# loss_mask           0.038
# loss_objectness     0.099
# loss_rpn_box_reg    0.002
#
# === 54 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.110
# loss_box_reg        0.009
# loss_mask           0.722
# loss_objectness     0.104
# loss_rpn_box_reg    0.001
#
# === 55 ===
# [img.shape for img in imgs] = [torch.Size([3, 687, 687])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.048
# loss_box_reg        0.004
# loss_mask           0.039
# loss_objectness     0.100
# loss_rpn_box_reg    0.004
#
# === 56 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.042
# loss_box_reg        0.003
# loss_mask           0.041
# loss_objectness     0.170
# loss_rpn_box_reg    0.036
#
# === 57 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.052
# loss_box_reg        0.004
# loss_mask           0.049
# loss_objectness     0.157
# loss_rpn_box_reg    0.004
#
# === 58 ===
# [img.shape for img in imgs] = [torch.Size([3, 1748, 1748])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.027
# loss_box_reg        0.002
# loss_mask           0.067
# loss_objectness     0.102
# loss_rpn_box_reg    0.018
#
# === 59 ===
# [img.shape for img in imgs] = [torch.Size([3, 717, 717])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.066
# loss_box_reg        0.003
# loss_mask           0.037
# loss_objectness     0.127
# loss_rpn_box_reg    0.003
#
# === 60 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.063
# loss_box_reg        0.003
# loss_mask           0.059
# loss_objectness     0.142
# loss_rpn_box_reg    0.005
#
# === 61 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.045
# loss_box_reg        0.004
# loss_mask           0.046
# loss_objectness     0.139
# loss_rpn_box_reg    0.004
#
# === 62 ===
# [img.shape for img in imgs] = [torch.Size([3, 1349, 1349])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.234
# loss_box_reg        0.050
# loss_mask           0.129
# loss_objectness     0.119
# loss_rpn_box_reg    0.013
#
# === 63 ===
# [img.shape for img in imgs] = [torch.Size([3, 2376, 2376])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.012
# loss_box_reg        0.000
# loss_mask           0.053
# loss_objectness     0.081
# loss_rpn_box_reg    0.002
#
# === 64 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.041
# loss_box_reg        0.002
# loss_mask           0.041
# loss_objectness     0.181
# loss_rpn_box_reg    0.003
#
# === 65 ===
# [img.shape for img in imgs] = [torch.Size([3, 1147, 1147])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.034
# loss_box_reg        0.002
# loss_mask           0.033
# loss_objectness     0.123
# loss_rpn_box_reg    0.003
#
# === 66 ===
# [img.shape for img in imgs] = [torch.Size([3, 1512, 1512])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.013
# loss_box_reg        0.001
# loss_mask           0.088
# loss_objectness     0.121
# loss_rpn_box_reg    0.003
#
# === 67 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.036
# loss_box_reg        0.002
# loss_mask           0.023
# loss_objectness     0.112
# loss_rpn_box_reg    0.001
#
# === 68 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.037
# loss_box_reg        0.004
# loss_mask           0.031
# loss_objectness     0.129
# loss_rpn_box_reg    0.012
#
# === 69 ===
# [img.shape for img in imgs] = [torch.Size([3, 2433, 2433])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.014
# loss_box_reg        0.001
# loss_mask           0.016
# loss_objectness     0.072
# loss_rpn_box_reg    0.008
#
# === 70 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.045
# loss_box_reg        0.006
# loss_mask           0.029
# loss_objectness     0.111
# loss_rpn_box_reg    0.002
#
# === 71 ===
# [img.shape for img in imgs] = [torch.Size([3, 1890, 1890])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.009
# loss_box_reg        0.000
# loss_mask           0.057
# loss_objectness     0.058
# loss_rpn_box_reg    0.001
#
# === 72 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.012
# loss_box_reg        0.003
# loss_mask           0.048
# loss_objectness     0.138
# loss_rpn_box_reg    0.007
#
# === 73 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.032
# loss_box_reg        0.004
# loss_mask           0.045
# loss_objectness     0.100
# loss_rpn_box_reg    0.002
#
# === 74 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.013
# loss_box_reg        0.001
# loss_mask           0.037
# loss_objectness     0.100
# loss_rpn_box_reg    0.006
#
# === 75 ===
# [img.shape for img in imgs] = [torch.Size([3, 1755, 1755])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.005
# loss_box_reg        0.001
# loss_mask           0.030
# loss_objectness     0.073
# loss_rpn_box_reg    0.008
#
# === 76 ===
# [img.shape for img in imgs] = [torch.Size([3, 1259, 1259])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.007
# loss_box_reg        0.000
# loss_mask           0.057
# loss_objectness     0.082
# loss_rpn_box_reg    0.005
#
# === 77 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.025
# loss_box_reg        0.001
# loss_mask           0.052
# loss_objectness     0.154
# loss_rpn_box_reg    0.033
#
# === 78 ===
# [img.shape for img in imgs] = [torch.Size([3, 2098, 2098])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.007
# loss_box_reg        0.000
# loss_mask           0.027
# loss_objectness     0.048
# loss_rpn_box_reg    0.006
#
# === 79 ===
# [img.shape for img in imgs] = [torch.Size([3, 1002, 1002])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.020
# loss_box_reg        0.000
# loss_mask           0.018
# loss_objectness     0.101
# loss_rpn_box_reg    0.017
#
# === 80 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.020
# loss_box_reg        0.000
# loss_mask           0.031
# loss_objectness     0.049
# loss_rpn_box_reg    0.001
#
# === 81 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.016
# loss_box_reg        0.002
# loss_mask           0.050
# loss_objectness     0.093
# loss_rpn_box_reg    0.011
#
# === 82 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.011
# loss_box_reg        0.000
# loss_mask           0.037
# loss_objectness     0.062
# loss_rpn_box_reg    0.001
#
# === 83 ===
# [img.shape for img in imgs] = [torch.Size([3, 2196, 2196])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.015
# loss_box_reg        0.000
# loss_mask           0.050
# loss_objectness     0.077
# loss_rpn_box_reg    0.023
#
# === 84 ===
# [img.shape for img in imgs] = [torch.Size([3, 1740, 1740])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.014
# loss_box_reg        0.000
# loss_mask           0.027
# loss_objectness     0.117
# loss_rpn_box_reg    0.017
#
# === 85 ===
# [img.shape for img in imgs] = [torch.Size([3, 2302, 2302])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.013
# loss_box_reg        0.001
# loss_mask           0.047
# loss_objectness     0.080
# loss_rpn_box_reg    0.002
#
# === 86 ===
# [img.shape for img in imgs] = [torch.Size([3, 2185, 2185])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.023
# loss_box_reg        0.012
# loss_mask           0.861
# loss_objectness     0.041
# loss_rpn_box_reg    0.001
#
# === 87 ===
# [img.shape for img in imgs] = [torch.Size([3, 2095, 2095])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.012
# loss_box_reg        0.000
# loss_mask           0.086
# loss_objectness     0.054
# loss_rpn_box_reg    0.006
#
# === 88 ===
# [img.shape for img in imgs] = [torch.Size([3, 660, 660])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.026
# loss_box_reg        0.001
# loss_mask           0.026
# loss_objectness     0.065
# loss_rpn_box_reg    0.004
#
# === 89 ===
# [img.shape for img in imgs] = [torch.Size([3, 996, 996])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.034
# loss_box_reg        0.008
# loss_mask           0.823
# loss_objectness     0.050
# loss_rpn_box_reg    0.002
#
# === 90 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.017
# loss_box_reg        0.002
# loss_mask           0.046
# loss_objectness     0.049
# loss_rpn_box_reg    0.004
#
# === 91 ===
# [img.shape for img in imgs] = [torch.Size([3, 683, 683])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.101
# loss_box_reg        0.064
# loss_mask           1.156
# loss_objectness     0.041
# loss_rpn_box_reg    0.004
#
# === 92 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.016
# loss_box_reg        0.002
# loss_mask           0.026
# loss_objectness     0.039
# loss_rpn_box_reg    0.001
#
# === 93 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.023
# loss_box_reg        0.001
# loss_mask           0.034
# loss_objectness     0.057
# loss_rpn_box_reg    0.005
#
# === 94 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.096
# loss_box_reg        0.062
# loss_mask           0.328
# loss_objectness     0.050
# loss_rpn_box_reg    0.004
#
# === 95 ===
# [img.shape for img in imgs] = [torch.Size([3, 1944, 1944])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.140
# loss_box_reg        0.076
# loss_mask           0.906
# loss_objectness     0.039
# loss_rpn_box_reg    0.003
#
# === 96 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.011
# loss_box_reg        0.001
# loss_mask           0.024
# loss_objectness     0.058
# loss_rpn_box_reg    0.003
#
# === 97 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.071
# loss_box_reg        0.033
# loss_mask           0.870
# loss_objectness     0.054
# loss_rpn_box_reg    0.003
#
# === 98 ===
# [img.shape for img in imgs] = [torch.Size([3, 851, 851])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.060
# loss_box_reg        0.026
# loss_mask           0.874
# loss_objectness     0.054
# loss_rpn_box_reg    0.001
#
# === 99 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.025
# loss_box_reg        0.001
# loss_mask           0.048
# loss_objectness     0.090
# loss_rpn_box_reg    0.010
#
# === 100 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.032
# loss_box_reg        0.005
# loss_mask           0.058
# loss_objectness     0.068
# loss_rpn_box_reg    0.017
#
# === 101 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.032
# loss_box_reg        0.010
# loss_mask           0.043
# loss_objectness     0.040
# loss_rpn_box_reg    0.002
#
# === 102 ===
# [img.shape for img in imgs] = [torch.Size([3, 1905, 1905])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.021
# loss_box_reg        0.003
# loss_mask           0.070
# loss_objectness     0.083
# loss_rpn_box_reg    0.009
#
# === 103 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.022
# loss_box_reg        0.006
# loss_mask           0.042
# loss_objectness     0.061
# loss_rpn_box_reg    0.002
#
# === 104 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.091
# loss_box_reg        0.042
# loss_mask           0.748
# loss_objectness     0.025
# loss_rpn_box_reg    0.001
#
# === 105 ===
# [img.shape for img in imgs] = [torch.Size([3, 1913, 1913])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.012
# loss_box_reg        0.004
# loss_mask           0.041
# loss_objectness     0.062
# loss_rpn_box_reg    0.001
#
# === 106 ===
# [img.shape for img in imgs] = [torch.Size([3, 884, 884])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.176
# loss_box_reg        0.125
# loss_mask           1.224
# loss_objectness     0.033
# loss_rpn_box_reg    0.005
#
# === 107 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.025
# loss_box_reg        0.010
# loss_mask           0.048
# loss_objectness     0.050
# loss_rpn_box_reg    0.002
#
# === 108 ===
# [img.shape for img in imgs] = [torch.Size([3, 1883, 1883])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.178
# loss_box_reg        0.132
# loss_mask           0.977
# loss_objectness     0.025
# loss_rpn_box_reg    0.003
#
# === 109 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.050
# loss_box_reg        0.058
# loss_mask           0.059
# loss_objectness     0.091
# loss_rpn_box_reg    0.033
#
# === 110 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.019
# loss_box_reg        0.005
# loss_mask           0.044
# loss_objectness     0.041
# loss_rpn_box_reg    0.002
#
# === 111 ===
# [img.shape for img in imgs] = [torch.Size([3, 897, 897])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.029
# loss_box_reg        0.016
# loss_mask           0.373
# loss_objectness     0.113
# loss_rpn_box_reg    0.057
#
# === 112 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.036
# loss_box_reg        0.019
# loss_mask           0.050
# loss_objectness     0.067
# loss_rpn_box_reg    0.019
#
# === 113 ===
# [img.shape for img in imgs] = [torch.Size([3, 2177, 2177])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.025
# loss_box_reg        0.002
# loss_mask           0.087
# loss_objectness     0.126
# loss_rpn_box_reg    0.010
#
# === 114 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.078
# loss_box_reg        0.100
# loss_mask           0.251
# loss_objectness     0.032
# loss_rpn_box_reg    0.002
#
# === 115 ===
# [img.shape for img in imgs] = [torch.Size([3, 2358, 2358])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.028
# loss_box_reg        0.003
# loss_mask           0.170
# loss_objectness     0.101
# loss_rpn_box_reg    0.011
#
# === 116 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.078
# loss_box_reg        0.056
# loss_mask           0.902
# loss_objectness     0.044
# loss_rpn_box_reg    0.008
#
# === 117 ===
# [img.shape for img in imgs] = [torch.Size([3, 1003, 1003])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.060
# loss_box_reg        0.032
# loss_mask           1.218
# loss_objectness     0.028
# loss_rpn_box_reg    0.001
#
# === 118 ===
# [img.shape for img in imgs] = [torch.Size([3, 2079, 2079])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.076
# loss_box_reg        0.044
# loss_mask           0.128
# loss_objectness     0.050
# loss_rpn_box_reg    0.010
#
# === 119 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.044
# loss_box_reg        0.040
# loss_mask           0.305
# loss_objectness     0.042
# loss_rpn_box_reg    0.006
#
# === 120 ===
# [img.shape for img in imgs] = [torch.Size([3, 2361, 2361])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.097
# loss_box_reg        0.076
# loss_mask           0.646
# loss_objectness     0.080
# loss_rpn_box_reg    0.017
#
# === 121 ===
# [img.shape for img in imgs] = [torch.Size([3, 1745, 1745])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.032
# loss_box_reg        0.011
# loss_mask           0.872
# loss_objectness     0.039
# loss_rpn_box_reg    0.003
#
# === 122 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.099
# loss_box_reg        0.094
# loss_mask           0.382
# loss_objectness     0.045
# loss_rpn_box_reg    0.001
#
# === 123 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.020
# loss_box_reg        0.000
# loss_mask           0.096
# loss_objectness     0.059
# loss_rpn_box_reg    0.007
#
# === 124 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.059
# loss_box_reg        0.023
# loss_mask           0.135
# loss_objectness     0.068
# loss_rpn_box_reg    0.007
#
# === 125 ===
# [img.shape for img in imgs] = [torch.Size([3, 1732, 1732])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.192
# loss_box_reg        0.107
# loss_mask           0.385
# loss_objectness     0.035
# loss_rpn_box_reg    0.002
#
# === 126 ===
# [img.shape for img in imgs] = [torch.Size([3, 1959, 1959])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.131
# loss_box_reg        0.069
# loss_mask           0.725
# loss_objectness     0.043
# loss_rpn_box_reg    0.002
#
# === 127 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.017
# loss_box_reg        0.005
# loss_mask           0.115
# loss_objectness     0.092
# loss_rpn_box_reg    0.010
#
# === 128 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.022
# loss_box_reg        0.008
# loss_mask           0.140
# loss_objectness     0.082
# loss_rpn_box_reg    0.009
#
# === 129 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.019
# loss_box_reg        0.005
# loss_mask           0.087
# loss_objectness     0.073
# loss_rpn_box_reg    0.003
#
# === 130 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.056
# loss_box_reg        0.048
# loss_mask           0.849
# loss_objectness     0.056
# loss_rpn_box_reg    0.006
#
# === 131 ===
# [img.shape for img in imgs] = [torch.Size([3, 1415, 1415])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.025
# loss_box_reg        0.010
# loss_mask           0.137
# loss_objectness     0.040
# loss_rpn_box_reg    0.008
#
# === 132 ===
# [img.shape for img in imgs] = [torch.Size([3, 2140, 2140])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.153
# loss_box_reg        0.101
# loss_mask           0.689
# loss_objectness     0.026
# loss_rpn_box_reg    0.002
#
# === 133 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.022
# loss_box_reg        0.009
# loss_mask           0.146
# loss_objectness     0.101
# loss_rpn_box_reg    0.010
#
# === 134 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.073
# loss_box_reg        0.065
# loss_mask           0.707
# loss_objectness     0.036
# loss_rpn_box_reg    0.004
#
# === 135 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.035
# loss_box_reg        0.015
# loss_mask           0.389
# loss_objectness     0.053
# loss_rpn_box_reg    0.001
#
# === 136 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.115
# loss_box_reg        0.099
# loss_mask           0.802
# loss_objectness     0.034
# loss_rpn_box_reg    0.002
#
# === 137 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.022
# loss_box_reg        0.005
# loss_mask           0.177
# loss_objectness     0.074
# loss_rpn_box_reg    0.015
#
# === 138 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.150
# loss_box_reg        0.187
# loss_mask           0.258
# loss_objectness     0.036
# loss_rpn_box_reg    0.003
#
# === 139 ===
# [img.shape for img in imgs] = [torch.Size([3, 1922, 1922])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.080
# loss_box_reg        0.030
# loss_mask           0.652
# loss_objectness     0.033
# loss_rpn_box_reg    0.007
#
# === 140 ===
# [img.shape for img in imgs] = [torch.Size([3, 1010, 1010])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.055
# loss_box_reg        0.033
# loss_mask           0.131
# loss_objectness     0.054
# loss_rpn_box_reg    0.015
#
# === 141 ===
# [img.shape for img in imgs] = [torch.Size([3, 956, 956])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.160
# loss_box_reg        0.118
# loss_mask           0.616
# loss_objectness     0.023
# loss_rpn_box_reg    0.002
#
# === 142 ===
# [img.shape for img in imgs] = [torch.Size([3, 963, 963])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.078
# loss_box_reg        0.061
# loss_mask           0.406
# loss_objectness     0.049
# loss_rpn_box_reg    0.003
#
# === 143 ===
# [img.shape for img in imgs] = [torch.Size([3, 1610, 1610])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.167
# loss_box_reg        0.127
# loss_mask           0.378
# loss_objectness     0.039
# loss_rpn_box_reg    0.002
#
# === 144 ===
# [img.shape for img in imgs] = [torch.Size([3, 2026, 2026])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.087
# loss_box_reg        0.058
# loss_mask           0.299
# loss_objectness     0.065
# loss_rpn_box_reg    0.015
#
# === 145 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.228
# loss_box_reg        0.247
# loss_mask           0.509
# loss_objectness     0.042
# loss_rpn_box_reg    0.002
#
# === 146 ===
# [img.shape for img in imgs] = [torch.Size([3, 1588, 1588])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.071
# loss_box_reg        0.004
# loss_mask           0.181
# loss_objectness     0.339
# loss_rpn_box_reg    0.007
#
# === 147 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.026
# loss_box_reg        0.009
# loss_mask           0.130
# loss_objectness     0.037
# loss_rpn_box_reg    0.002
#
# === 148 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.176
# loss_box_reg        0.148
# loss_mask           0.594
# loss_objectness     0.026
# loss_rpn_box_reg    0.003
#
# === 149 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.164
# loss_box_reg        0.086
# loss_mask           0.299
# loss_objectness     0.034
# loss_rpn_box_reg    0.005
#
# === 150 ===
# [img.shape for img in imgs] = [torch.Size([3, 1923, 1923])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.013
# loss_box_reg        0.003
# loss_mask           0.198
# loss_objectness     0.117
# loss_rpn_box_reg    0.020
#
# === 151 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.029
# loss_box_reg        0.014
# loss_mask           0.218
# loss_objectness     0.064
# loss_rpn_box_reg    0.019
#
# === 152 ===
# [img.shape for img in imgs] = [torch.Size([3, 658, 658])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.026
# loss_box_reg        0.014
# loss_mask           0.175
# loss_objectness     0.032
# loss_rpn_box_reg    0.005
#
# === 153 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.134
# loss_box_reg        0.117
# loss_mask           0.610
# loss_objectness     0.047
# loss_rpn_box_reg    0.003
#
# === 154 ===
# [img.shape for img in imgs] = [torch.Size([3, 897, 897])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.379
# loss_box_reg        0.340
# loss_mask           0.385
# loss_objectness     0.037
# loss_rpn_box_reg    0.006
#
# === 155 ===
# [img.shape for img in imgs] = [torch.Size([3, 1195, 1195])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.398
# loss_box_reg        0.350
# loss_mask           0.549
# loss_objectness     0.037
# loss_rpn_box_reg    0.003
#
# === 156 ===
# [img.shape for img in imgs] = [torch.Size([3, 2130, 2130])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.107
# loss_box_reg        0.062
# loss_mask           0.565
# loss_objectness     0.031
# loss_rpn_box_reg    0.001
#
# === 157 ===
# [img.shape for img in imgs] = [torch.Size([3, 1864, 1864])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.085
# loss_box_reg        0.095
# loss_mask           0.537
# loss_objectness     0.035
# loss_rpn_box_reg    0.003
#
# === 158 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.021
# loss_box_reg        0.008
# loss_mask           0.159
# loss_objectness     0.053
# loss_rpn_box_reg    0.002
#
# === 159 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.157
# loss_box_reg        0.176
# loss_mask           0.212
# loss_objectness     0.056
# loss_rpn_box_reg    0.010
#
# === 160 ===
# [img.shape for img in imgs] = [torch.Size([3, 1793, 1793])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.017
# loss_box_reg        0.011
# loss_mask           0.169
# loss_objectness     0.052
# loss_rpn_box_reg    0.016
#
# === 161 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.019
# loss_box_reg        0.014
# loss_mask           0.168
# loss_objectness     0.033
# loss_rpn_box_reg    0.002
#
# === 162 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.128
# loss_box_reg        0.279
# loss_mask           0.399
# loss_objectness     0.042
# loss_rpn_box_reg    0.001
#
# === 163 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.046
# loss_box_reg        0.005
# loss_mask           0.166
# loss_objectness     0.124
# loss_rpn_box_reg    0.032
#
# === 164 ===
# [img.shape for img in imgs] = [torch.Size([3, 872, 872])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.231
# loss_box_reg        0.117
# loss_mask           0.328
# loss_objectness     0.046
# loss_rpn_box_reg    0.005
#
# === 165 ===
# [img.shape for img in imgs] = [torch.Size([3, 755, 755])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.023
# loss_box_reg        0.022
# loss_mask           0.130
# loss_objectness     0.034
# loss_rpn_box_reg    0.004
#
# === 166 ===
# [img.shape for img in imgs] = [torch.Size([3, 2155, 2155])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.039
# loss_box_reg        0.046
# loss_mask           0.690
# loss_objectness     0.044
# loss_rpn_box_reg    0.004
#
# === 167 ===
# [img.shape for img in imgs] = [torch.Size([3, 2228, 2228])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.088
# loss_box_reg        0.119
# loss_mask           0.742
# loss_objectness     0.024
# loss_rpn_box_reg    0.002
#
# === 168 ===
# [img.shape for img in imgs] = [torch.Size([3, 2321, 2321])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.066
# loss_box_reg        0.097
# loss_mask           0.254
# loss_objectness     0.029
# loss_rpn_box_reg    0.003
#
# === 169 ===
# [img.shape for img in imgs] = [torch.Size([3, 789, 789])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.051
# loss_box_reg        0.060
# loss_mask           0.338
# loss_objectness     0.040
# loss_rpn_box_reg    0.001
#
# === 170 ===
# [img.shape for img in imgs] = [torch.Size([3, 811, 811])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.056
# loss_box_reg        0.056
# loss_mask           0.429
# loss_objectness     0.040
# loss_rpn_box_reg    0.002
#
# === 171 ===
# [img.shape for img in imgs] = [torch.Size([3, 753, 753])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.017
# loss_box_reg        0.005
# loss_mask           0.136
# loss_objectness     0.084
# loss_rpn_box_reg    0.009
#
# === 172 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.236
# loss_box_reg        0.268
# loss_mask           0.373
# loss_objectness     0.034
# loss_rpn_box_reg    0.001
#
# === 173 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.115
# loss_box_reg        0.168
# loss_mask           0.635
# loss_objectness     0.040
# loss_rpn_box_reg    0.003
#
# === 174 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.037
# loss_box_reg        0.012
# loss_mask           0.135
# loss_objectness     0.078
# loss_rpn_box_reg    0.005
#
# === 175 ===
# [img.shape for img in imgs] = [torch.Size([3, 2322, 2322])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.047
# loss_box_reg        0.007
# loss_mask           0.135
# loss_objectness     0.070
# loss_rpn_box_reg    0.009
#
# === 176 ===
# [img.shape for img in imgs] = [torch.Size([3, 2422, 2422])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.090
# loss_box_reg        0.075
# loss_mask           0.474
# loss_objectness     0.095
# loss_rpn_box_reg    0.009
#
# === 177 ===
# [img.shape for img in imgs] = [torch.Size([3, 1916, 1916])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.031
# loss_box_reg        0.005
# loss_mask           0.144
# loss_objectness     0.085
# loss_rpn_box_reg    0.007
#
# === 178 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.126
# loss_box_reg        0.168
# loss_mask           0.861
# loss_objectness     0.042
# loss_rpn_box_reg    0.009
#
# === 179 ===
# [img.shape for img in imgs] = [torch.Size([3, 2285, 2285])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.031
# loss_box_reg        0.025
# loss_mask           0.543
# loss_objectness     0.031
# loss_rpn_box_reg    0.001
#
# === 180 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.181
# loss_box_reg        0.128
# loss_mask           0.228
# loss_objectness     0.053
# loss_rpn_box_reg    0.009
#
# === 181 ===
# [img.shape for img in imgs] = [torch.Size([3, 1236, 1236])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.175
# loss_box_reg        0.156
# loss_mask           0.313
# loss_objectness     0.047
# loss_rpn_box_reg    0.002
#
# === 182 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.107
# loss_box_reg        0.104
# loss_mask           0.284
# loss_objectness     0.046
# loss_rpn_box_reg    0.004
#
# === 183 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.131
# loss_box_reg        0.112
# loss_mask           0.363
# loss_objectness     0.047
# loss_rpn_box_reg    0.002
#
# === 184 ===
# [img.shape for img in imgs] = [torch.Size([3, 2545, 2545])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.034
# loss_box_reg        0.020
# loss_mask           0.495
# loss_objectness     0.042
# loss_rpn_box_reg    0.014
#
# === 185 ===
# [img.shape for img in imgs] = [torch.Size([3, 2541, 2541])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.130
# loss_box_reg        0.089
# loss_mask           0.498
# loss_objectness     0.086
# loss_rpn_box_reg    0.009
#
# === 186 ===
# [img.shape for img in imgs] = [torch.Size([3, 1264, 1264])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.075
# loss_box_reg        0.023
# loss_mask           0.245
# loss_objectness     0.052
# loss_rpn_box_reg    0.012
#
# === 187 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.045
# loss_box_reg        0.035
# loss_mask           0.787
# loss_objectness     0.036
# loss_rpn_box_reg    0.004
#
# === 188 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# ...
#
# === 340 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.173
# loss_box_reg        0.171
# loss_mask           0.329
# loss_objectness     0.025
# loss_rpn_box_reg    0.003
#
# === 341 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.131
# loss_box_reg        0.121
# loss_mask           0.538
# loss_objectness     0.024
# loss_rpn_box_reg    0.001
#
# === 342 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.150
# loss_box_reg        0.094
# loss_mask           0.229
# loss_objectness     0.029
# loss_rpn_box_reg    0.004
#
# === 343 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.094
# loss_box_reg        0.070
# loss_mask           0.497
# loss_objectness     0.027
# loss_rpn_box_reg    0.001
#
# === 344 ===
# [img.shape for img in imgs] = [torch.Size([3, 1759, 1759])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.108
# loss_box_reg        0.097
# loss_mask           0.623
# loss_objectness     0.018
# loss_rpn_box_reg    0.001
#
# === 345 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.126
# loss_box_reg        0.117
# loss_mask           0.312
# loss_objectness     0.027
# loss_rpn_box_reg    0.002
#
# === 346 ===
# [img.shape for img in imgs] = [torch.Size([3, 665, 665])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.068
# loss_box_reg        0.048
# loss_mask           0.496
# loss_objectness     0.042
# loss_rpn_box_reg    0.001
#
# === 347 ===
# [img.shape for img in imgs] = [torch.Size([3, 2361, 2361])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.039
# loss_box_reg        0.004
# loss_mask           0.158
# loss_objectness     0.141
# loss_rpn_box_reg    0.025
#
# === 348 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.071
# loss_box_reg        0.040
# loss_mask           0.446
# loss_objectness     0.026
# loss_rpn_box_reg    0.001
#
# === 349 ===
# [img.shape for img in imgs] = [torch.Size([3, 1849, 1849])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.135
# loss_box_reg        0.094
# loss_mask           0.518
# loss_objectness     0.019
# loss_rpn_box_reg    0.001
#
# === 350 ===
# [img.shape for img in imgs] = [torch.Size([3, 1132, 1132])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.036
# loss_box_reg        0.021
# loss_mask           0.297
# loss_objectness     0.066
# loss_rpn_box_reg    0.020
#
# === 351 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.083
# loss_box_reg        0.088
# loss_mask           0.300
# loss_objectness     0.069
# loss_rpn_box_reg    0.031
#
# === 352 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.114
# loss_box_reg        0.097
# loss_mask           0.672
# loss_objectness     0.034
# loss_rpn_box_reg    0.005
#
# === 353 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.131
# loss_box_reg        0.105
# loss_mask           0.221
# loss_objectness     0.051
# loss_rpn_box_reg    0.022
#
# === 354 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.030
# loss_box_reg        0.004
# loss_mask           0.126
# loss_objectness     0.066
# loss_rpn_box_reg    0.004
#
# === 355 ===
# [img.shape for img in imgs] = [torch.Size([3, 937, 937])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.202
# loss_box_reg        0.105
# loss_mask           0.622
# loss_objectness     0.036
# loss_rpn_box_reg    0.002
#
# === 356 ===
# [img.shape for img in imgs] = [torch.Size([3, 2458, 2458])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.121
# loss_box_reg        0.072
# loss_mask           0.468
# loss_objectness     0.018
# loss_rpn_box_reg    0.002
#
# === 357 ===
# [img.shape for img in imgs] = [torch.Size([3, 2428, 2428])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.090
# loss_box_reg        0.070
# loss_mask           0.300
# loss_objectness     0.017
# loss_rpn_box_reg    0.008
#
# === 358 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.084
# loss_box_reg        0.049
# loss_mask           0.498
# loss_objectness     0.041
# loss_rpn_box_reg    0.002
#
# === 359 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.102
# loss_box_reg        0.053
# loss_mask           0.387
# loss_objectness     0.047
# loss_rpn_box_reg    0.006
#
# === 360 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.105
# loss_box_reg        0.118
# loss_mask           0.236
# loss_objectness     0.043
# loss_rpn_box_reg    0.010
#
# === 361 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.195
# loss_box_reg        0.178
# loss_mask           0.537
# loss_objectness     0.034
# loss_rpn_box_reg    0.001
#
# === 362 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.090
# loss_box_reg        0.038
# loss_mask           0.313
# loss_objectness     0.032
# loss_rpn_box_reg    0.003
#
# === 363 ===
# [img.shape for img in imgs] = [torch.Size([3, 940, 940])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.087
# loss_box_reg        0.052
# loss_mask           0.629
# loss_objectness     0.032
# loss_rpn_box_reg    0.008
#
# === 364 ===
# [img.shape for img in imgs] = [torch.Size([3, 1355, 1355])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.062
# loss_box_reg        0.025
# loss_mask           0.721
# loss_objectness     0.039
# loss_rpn_box_reg    0.016
#
# === 365 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.154
# loss_box_reg        0.135
# loss_mask           0.581
# loss_objectness     0.037
# loss_rpn_box_reg    0.005
#
# === 366 ===
# [img.shape for img in imgs] = [torch.Size([3, 764, 764])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.164
# loss_box_reg        0.151
# loss_mask           0.513
# loss_objectness     0.036
# loss_rpn_box_reg    0.002
#
# === 367 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.141
# loss_box_reg        0.136
# loss_mask           0.263
# loss_objectness     0.022
# loss_rpn_box_reg    0.002
#
# === 368 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.150
# loss_box_reg        0.141
# loss_mask           0.423
# loss_objectness     0.027
# loss_rpn_box_reg    0.001
#
# === 369 ===
# [img.shape for img in imgs] = [torch.Size([3, 1499, 1499])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.026
# loss_box_reg        0.002
# loss_mask           0.216
# loss_objectness     0.054
# loss_rpn_box_reg    0.004
#
# === 370 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.051
# loss_box_reg        0.034
# loss_mask           0.394
# loss_objectness     0.034
# loss_rpn_box_reg    0.010
#
# === 371 ===
# [img.shape for img in imgs] = [torch.Size([3, 1338, 1338])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.132
# loss_box_reg        0.115
# loss_mask           0.547
# loss_objectness     0.026
# loss_rpn_box_reg    0.006
#
# === 372 ===
# [img.shape for img in imgs] = [torch.Size([3, 798, 798])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.198
# loss_box_reg        0.145
# loss_mask           0.263
# loss_objectness     0.026
# loss_rpn_box_reg    0.003
#
# === 373 ===
# [img.shape for img in imgs] = [torch.Size([3, 2514, 2514])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.074
# loss_box_reg        0.093
# loss_mask           0.266
# loss_objectness     0.026
# loss_rpn_box_reg    0.002
#
# === 374 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.120
# loss_box_reg        0.145
# loss_mask           0.293
# loss_objectness     0.018
# loss_rpn_box_reg    0.001
#
# === 375 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.084
# loss_box_reg        0.040
# loss_mask           0.210
# loss_objectness     0.039
# loss_rpn_box_reg    0.008
#
# === 376 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.101
# loss_box_reg        0.071
# loss_mask           0.424
# loss_objectness     0.027
# loss_rpn_box_reg    0.004
#
# === 377 ===
# [img.shape for img in imgs] = [torch.Size([3, 2465, 2465])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.186
# loss_box_reg        0.164
# loss_mask           0.504
# loss_objectness     0.016
# loss_rpn_box_reg    0.001
#
# === 378 ===
# [img.shape for img in imgs] = [torch.Size([3, 1284, 1284])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.133
# loss_box_reg        0.082
# loss_mask           0.676
# loss_objectness     0.020
# loss_rpn_box_reg    0.004
#
# === 379 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.079
# loss_box_reg        0.083
# loss_mask           0.272
# loss_objectness     0.068
# loss_rpn_box_reg    0.028
#
# === 380 ===
# [img.shape for img in imgs] = [torch.Size([3, 2130, 2130])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.080
# loss_box_reg        0.078
# loss_mask           0.410
# loss_objectness     0.015
# loss_rpn_box_reg    0.001
#
# === 381 ===
# [img.shape for img in imgs] = [torch.Size([3, 2149, 2149])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.160
# loss_box_reg        0.154
# loss_mask           0.321
# loss_objectness     0.020
# loss_rpn_box_reg    0.001
#
# === 382 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.134
# loss_box_reg        0.129
# loss_mask           0.381
# loss_objectness     0.028
# loss_rpn_box_reg    0.004
#
# === 383 ===
# [img.shape for img in imgs] = [torch.Size([3, 1631, 1631])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.060
# loss_box_reg        0.022
# loss_mask           0.741
# loss_objectness     0.023
# loss_rpn_box_reg    0.004
#
# === 384 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.024
# loss_box_reg        0.004
# loss_mask           0.181
# loss_objectness     0.149
# loss_rpn_box_reg    0.031
#
# === 385 ===
# [img.shape for img in imgs] = [torch.Size([3, 2460, 2460])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.112
# loss_box_reg        0.086
# loss_mask           0.453
# loss_objectness     0.029
# loss_rpn_box_reg    0.006
#
# === 386 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.116
# loss_box_reg        0.102
# loss_mask           0.244
# loss_objectness     0.028
# loss_rpn_box_reg    0.011
#
# === 387 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.095
# loss_box_reg        0.093
# loss_mask           0.301
# loss_objectness     0.024
# loss_rpn_box_reg    0.003
#
# === 388 ===
# [img.shape for img in imgs] = [torch.Size([3, 1007, 1007])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.090
# loss_box_reg        0.085
# loss_mask           0.336
# loss_objectness     0.037
# loss_rpn_box_reg    0.002
#
# === 389 ===
# [img.shape for img in imgs] = [torch.Size([3, 2041, 2041])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.057
# loss_box_reg        0.038
# loss_mask           0.424
# loss_objectness     0.036
# loss_rpn_box_reg    0.002
#
# === 390 ===
# [img.shape for img in imgs] = [torch.Size([3, 1062, 1062])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.063
# loss_box_reg        0.030
# loss_mask           0.749
# loss_objectness     0.041
# loss_rpn_box_reg    0.006
#
# === 391 ===
# [img.shape for img in imgs] = [torch.Size([3, 1057, 1057])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.099
# loss_box_reg        0.101
# loss_mask           0.430
# loss_objectness     0.034
# loss_rpn_box_reg    0.001
#
# === 392 ===
# [img.shape for img in imgs] = [torch.Size([3, 1094, 1094])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.109
# loss_box_reg        0.159
# loss_mask           0.266
# loss_objectness     0.015
# loss_rpn_box_reg    0.002
#
# === 393 ===
# [img.shape for img in imgs] = [torch.Size([3, 1950, 1950])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.059
# loss_box_reg        0.022
# loss_mask           0.671
# loss_objectness     0.036
# loss_rpn_box_reg    0.012
#
# === 394 ===
# [img.shape for img in imgs] = [torch.Size([3, 2130, 2130])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.070
# loss_box_reg        0.060
# loss_mask           0.263
# loss_objectness     0.046
# loss_rpn_box_reg    0.017
#
# === 395 ===
# [img.shape for img in imgs] = [torch.Size([3, 1128, 1128])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.121
# loss_box_reg        0.122
# loss_mask           0.238
# loss_objectness     0.033
# loss_rpn_box_reg    0.010
#
# === 396 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.101
# loss_box_reg        0.088
# loss_mask           0.457
# loss_objectness     0.033
# loss_rpn_box_reg    0.003
#
# === 397 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.115
# loss_box_reg        0.072
# loss_mask           0.541
# loss_objectness     0.039
# loss_rpn_box_reg    0.003
#
# === 398 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.052
# loss_box_reg        0.028
# loss_mask           0.593
# loss_objectness     0.051
# loss_rpn_box_reg    0.013
#
# === 399 ===
# [img.shape for img in imgs] = [torch.Size([3, 640, 640])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.063
# loss_box_reg        0.047
# loss_mask           0.296
# loss_objectness     0.060
# loss_rpn_box_reg    0.015
#
# === 400 ===
# [img.shape for img in imgs] = [torch.Size([3, 1195, 1195])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.148
# loss_box_reg        0.121
# loss_mask           0.267
# loss_objectness     0.027
# loss_rpn_box_reg    0.001
#
# === 401 ===
# [img.shape for img in imgs] = [torch.Size([3, 723, 723])]
# [type(target) for target in targets] = [<class 'dict'>]
# loss_classifier     0.135
# loss_box_reg        0.107
# loss_mask           0.422
# loss_objectness     0.025
# loss_rpn_box_reg    0.002

# %% [markdown]
# ## Training References
#
# From there, you can check out the [torchvision references](https://github.com/pytorch/vision/tree/main/references) where you'll find
# the actual training scripts we use to train our models.
#
# **Disclaimer** The code in our references is more complex than what you'll
# need for your own use-cases: this is because we're supporting different
# backends (PIL, tensors, TVTensors) and different transforms namespaces (v1 and
# v2). So don't be afraid to simplify and only keep what you need.
